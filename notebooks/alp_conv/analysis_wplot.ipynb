# %% [markdown]
# Analysis the results under new code

# %%
import sys
sys.path.append("../../mypkg")

# %%
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
from numbers import Number

from joblib import Parallel, delayed

from easydict import EasyDict as edict
from tqdm import trange, tqdm
from scipy.io import loadmat
from pprint import pprint
import itertools
from scipy.stats import chi2
from IPython.display import display
import pandas as pd
from collections import defaultdict as ddict

# %%
from constants import DATA_ROOT, RES_ROOT, FIG_ROOT, MIDRES_ROOT

from utils.misc import save_pkl, load_pkl, get_local_min_idxs
from utils import colors

# %%
import logging
from optimization.opt import logger as logger1
logger1.handlers[0].setLevel(logging.WARNING)

plt.style.use(FIG_ROOT/"base.mplstyle")
torch.set_default_dtype(torch.float64)

# %%
def _get_min_idx(x):
    """Get the index of the minimal values among the local minimals.
       If there are multiple ones, return the largest index
       args:
           x: a vec
        
    """
    x = np.array(x)
    lmin_idxs = get_local_min_idxs(x);
    if len(lmin_idxs) == 0:
        lmin_idxs = np.arange(len(x))
    lmin_idxs_inv =  lmin_idxs[::-1]
    lmins_inv = x[lmin_idxs_inv];
    return  lmin_idxs_inv[np.argmin(lmins_inv)]

def get_ci(est_alp, cov_mat, alp_idx, qv=1.96):
    ci_lim = qv*cov_mat[alp_idx, alp_idx].sqrt().item()
    ci = [est_alp[alp_idx].item()-ci_lim,  est_alp[alp_idx].item()+ci_lim]
    return ci
def get_alp_cov(hdf_fit):
    Q_mat = hdf_fit.hypo_utils.Q_mat_part
    Q_mat_inv = torch.linalg.pinv(Q_mat, hermitian=True, rtol=1e-7)
    Sig_mat = hdf_fit.hypo_utils.Sig_mat_part
    Cov_mat = Q_mat_inv @ Sig_mat @  Q_mat_inv / hdf_fit.data_params.n
    return Cov_mat[:hdf_fit.data_params.q,:hdf_fit.data_params.q];

# %%
ns = [100, 200, 400, 800, 1600, 3200]
num_rep = 1000
cols = colors.div_cmap(2)
norm_ci = 0.95
qv = np.abs(scipy.stats.norm.ppf((1-norm_ci)/2))
gt_alp = np.array([5, -1, 2])
# Out:
# array([ 5, -1,  2])

# %%
def _get_res(is_logi):
    if is_logi:
        all_res = load_pkl(RES_ROOT/f"conv_simu_res/simu_logi_alpconv_n100/all-valsel-metrics.pkl")
    else:
        all_res = load_pkl(RES_ROOT/f"conv_simu_res/simu_alpconv_n100/all-valsel-metrics.pkl")
    all_coms = np.array(list(all_res.keys()))
    can_Ns = np.sort(np.unique(all_coms[:, 1]))
    can_lams = np.sort(np.unique(all_coms[:, 2]));
    
    def _run_fn1(seed, all_cv_errs):
        errs_mat = []
        for cur_N in can_Ns:
            errs = []
            for cur_lam in can_lams:
                if is_logi:
                    errs.append(all_cv_errs[(seed, cur_N, cur_lam)].entropy_loss)
                else:
                    errs.append(all_cv_errs[(seed, cur_N, cur_lam)].mse_loss)
            errs_mat.append(errs)
        errs_mat = np.array(errs_mat)
        return errs_mat
    opt_lamNs_fix = {}
    for n in ns:
        if is_logi:
            cur_save_dir = RES_ROOT/f"conv_simu_res/simu_logi_alpconv_n{n}"
        else:
            cur_save_dir = RES_ROOT/f"conv_simu_res/simu_alpconv_n{n}"
        all_cv_errs = load_pkl(cur_save_dir/f"all-valsel-metrics.pkl")
        num_seed = len(np.unique(list(map(lambda x: x[0], all_cv_errs.keys()))))
        # do not make n_jobs>1, it is very slow
        with Parallel(n_jobs=1) as parallel:
            err_ten = parallel(delayed(_run_fn1)(cur_seed, all_cv_errs)  
                                     for cur_seed in tqdm(range(num_seed), 
                                                          total=num_seed, desc=f"n: {n}"))
        err_ten = np.array(err_ten);
        
        err_ten_ses = err_ten.std(axis=0)/np.sqrt(err_ten.shape[0])
        err_m = np.mean(np.array(err_ten), axis=0)
        errs = []
        for err in err_m:
            lam_min_idx = _get_min_idx(err)
            errs.append((err[lam_min_idx], lam_min_idx))
        errs = np.array(errs)
        N_min_idx = np.argmin(errs[:, 0]);
        lam_min_idx = int(errs[N_min_idx][1]);
        print(n, can_Ns[N_min_idx], can_lams[lam_min_idx])
        opt_lamNs_fix[n] = (can_Ns[N_min_idx],  can_lams[lam_min_idx])
    
    
    ress_dict = {}
    for n in ns:
        if is_logi:
            cur_save_dir = RES_ROOT/f"conv_simu_res/simu_logi_alpconv_n{n}"
        else:
            cur_save_dir = RES_ROOT/f"conv_simu_res/simu_alpconv_n{n}"
        cur_N, cur_lam = opt_lamNs_fix[n]
        def _run_fn_test(cur_seed):
            from optimization.opt import logger as logger1
            logger1.handlers[0].setLevel(logging.WARNING)
            torch.set_default_dtype(torch.float64)
            f1_name = f"seed_{cur_seed:.0f}-lam_{cur_lam*1000:.0f}-N_{cur_N:.0f}_fit.pkl"
            res1 = load_pkl(cur_save_dir/f1_name, verbose=False);
            res = edict()
            res.est_alp = res1.est_alp
            res.cov_mat = get_alp_cov(res1)
            res.ci_lens = np.zeros(len(gt_alp)-1)
            res.cov_probs = np.zeros(len(gt_alp)-1)
            for alp_idx in range(1, res1.data_params.q):
                ci = get_ci(res.est_alp, res.cov_mat, alp_idx=alp_idx, qv=qv) 
                res.cov_probs[alp_idx-1] = np.bitwise_and(ci[0] <= gt_alp[alp_idx], 
                                                          ci[1] >= gt_alp[alp_idx]).mean()
                res.ci_lens[alp_idx-1]= np.diff(ci)
            
            res.err = np.linalg.norm(res.est_alp[1:]-gt_alp[1:])
            return res 
        with Parallel(n_jobs=1) as parallel:
            ress = parallel(delayed(_run_fn_test)(cur_seed) for cur_seed in tqdm(range(num_rep), desc=f"n: {n}", 
                                                                                 total=num_rep))
        ress_dict[n] = ress
        
    err_infos = []
    cov_prob_infos = []
    for n in ns:
        ress = ress_dict[n]
        errs = np.array([res.err for res in ress])
        err_cilim = qv*errs.std()/np.sqrt(len(errs))
        errq1, errq3 = np.quantile(errs, [0.25, 0.72])
        err_info = [errs.mean(), 
                    errq1,
                    errq3]
        #err_info = [errs.mean(), 
        #             errs.mean()-err_cilim, 
        #             errs.mean()+err_cilim]
        
        cov_prob = np.array([res.cov_probs for res in ress])
        cov_prob_mean = cov_prob.mean(axis=0);
        cov_prob_cilim = 1.96 * cov_prob.std(axis=0)/np.sqrt(len(ress))
        cov_prob_info = np.array([
            cov_prob_mean, 
            cov_prob_mean-cov_prob_cilim,
            cov_prob_mean+cov_prob_cilim,
        ])
        
        err_infos.append(err_info)
        cov_prob_infos.append(cov_prob_info)
    
    err_infos = np.array(err_infos)
    cov_prob_infos = np.array(cov_prob_infos);
    
    return err_infos, cov_prob_infos

# %%
res_linear = _get_res(is_logi=False);
# Out:
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_alpconv_n100/all-valsel-metrics.pkl
# n: 100:  83%|████████████████████████████████████████████████████████████████████████████████▍                | 829/1000 [04:21<00:53,  3.17it/s]
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_alpconv_n100/all-valsel-metrics.pkl
# n: 100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 8644.04it/s]
# 100 12.0 1.4
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_alpconv_n200/all-valsel-metrics.pkl
# n: 200: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 8626.88it/s]
# 200 12.0 1.0
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_alpconv_n400/all-valsel-metrics.pkl
# n: 400: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 8307.77it/s]
# 400 10.0 0.6
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_alpconv_n800/all-valsel-metrics.pkl
# n: 800: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 8396.67it/s]
# 800 10.0 0.5
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_alpconv_n1600/all-valsel-metrics.pkl
# n: 1600: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 7817.90it/s]
# 1600 10.0 0.4
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_alpconv_n3200/all-valsel-metrics.pkl
# n: 3200: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 8365.02it/s]
# 3200 10.0 0.3
# n: 100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:10<00:00, 93.15it/s]
# n: 200: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:39<00:00, 25.22it/s]
# n: 400: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:40<00:00, 24.53it/s]
# n: 800: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:29<00:00, 33.93it/s]
# n: 1600: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:35<00:00, 27.88it/s]
# n: 3200: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:42<00:00, 23.60it/s]

# %%
res_logi = _get_res(is_logi=True);
# Out:
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_logi_alpconv_n100/all-valsel-metrics.pkl
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_logi_alpconv_n100/all-valsel-metrics.pkl
# n: 100: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 19933.01it/s]
# 100 10.0 0.4
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_logi_alpconv_n200/all-valsel-metrics.pkl
# n: 200: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 16521.46it/s]
# 200 6.0 0.2
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_logi_alpconv_n400/all-valsel-metrics.pkl
# n: 400: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 15333.14it/s]
# 400 8.0 0.2
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_logi_alpconv_n800/all-valsel-metrics.pkl
# n: 800: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 14882.39it/s]
# 800 8.0 0.2
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_logi_alpconv_n1600/all-valsel-metrics.pkl
# n: 1600: 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 15157.49it/s]
# 1600 8.0 0.2
# Load file /data/rajlab1/user_data/jin/MyResearch/HDF_infer/notebooks/alp_conv/../../mypkg/../results/conv_simu_res/simu_logi_alpconv_n3200/all-valsel-metrics.pkl
# n: 3200: 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 15022.31it/s]
# 3200 10.0 0.2
# n: 100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:53<00:00, 18.79it/s]
# n: 200: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:47<00:00, 21.00it/s]
# n: 400: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:42<00:00, 23.28it/s]
# n: 800: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:33<00:00, 29.78it/s]
# n: 1600: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:46<00:00, 21.61it/s]
# n: 3200: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:49<00:00, 20.01it/s]

# %%
plt.figure(figsize=[7, 10])
alp_ix = 0
plt.plot(ns, res_linear[1][:, 0, alp_ix], "*-",
         label=f"Linear", 
         linewidth=3,
         color=cols[0])
#plt.fill_between(ns, res_linear[1][:, 1, alp_ix], res_linear[1][:, 2, alp_ix], 
#    color=cols[0], alpha=0.5)
plt.plot(ns, res_logi[1][:, 0, alp_ix], "o-",
         label=f"Logistic", 
         linewidth=3,
         color=cols[1])
#plt.fill_between(ns, res_logi[1][:, 1, alp_ix], res_logi[1][:, 2, alp_ix], 
#    color=cols[1], alpha=0.5)
plt.xscale("log")
plt.ylabel("Empirical coverage probability")
plt.xlabel("Sample size")
plt.xlabel("Sample size (n)")
plt.title(r"$\alpha_{01}$", fontsize=20)
plt.axhline(y=norm_ci, ls="--", color="black")
plt.legend(loc="lower right")
plt.savefig(FIG_ROOT/"alp1_CI_nointv.jpg")

plt.figure(figsize=[7, 10])
alp_ix = 1
plt.plot(ns, res_linear[1][:, 0, alp_ix], "*-",
         label=f"Linear", 
         linewidth=3,
         color=cols[0])
#plt.fill_between(ns, res_linear[1][:, 1, alp_ix], res_linear[1][:, 2, alp_ix], 
#    color=cols[0], alpha=0.5)
plt.plot(ns, res_logi[1][:, 0, alp_ix], "o-",
         label=f"Logistic", 
         linewidth=3,
         color=cols[1])
#plt.fill_between(ns, res_logi[1][:, 1, alp_ix], res_logi[1][:, 2, alp_ix], 
#    color=cols[1], alpha=0.5)
plt.xscale("log")
plt.ylabel("Empirical coverage probability")
plt.xlabel("Sample size (n)")
plt.title(r"$\alpha_{02}$", fontsize=20)
plt.axhline(y=norm_ci, ls="--", color="black")
plt.legend(loc="lower right")
plt.savefig(FIG_ROOT/"alp2_CI_nointv.jpg")

plt.figure(figsize=[7, 10])
plt.plot(ns, res_linear[0][:, 0], "*-",
         label=f"Linear", 
         linewidth=3,
         color=cols[0])
plt.fill_between(ns, res_linear[0][:, 1], res_linear[0][:, 2], 
                     color=cols[0], alpha=0.5)
plt.plot(ns, res_logi[0][:, 0], "o-",
         label=f"Logistic", 
         linewidth=3,
         color=cols[1])
plt.fill_between(ns, res_logi[0][:, 1], res_logi[0][:, 2], 
                     color=cols[1], alpha=0.5)
plt.xlabel("Sample size (n)")
#plt.ylabel(r"$\sqrt{(\alpha_{01}-\widehat{\alpha_1})^2+(\alpha_{02}-\widehat{\alpha_2})^2}$")
plt.ylabel(r"$\|\widehat{\mathbf{\alpha}}-\mathbf{\alpha}_0\|_2$")
plt.xscale("log")
plt.legend()
plt.savefig(FIG_ROOT/"alp_con.jpg")
